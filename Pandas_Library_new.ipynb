# %%
import pandas as pd
#from pandas import *

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e63b7caa-1a22-4b5d-bdde-305912893e32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e63b7caa-1a22-4b5d-bdde-305912893e32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ship= pd.read_csv('titanic.csv')
ship
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         0                     Allison, Miss. Helen Loraine
# 2          1         0             Allison, Mr. Hudson Joshua Creighton
# 3          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 4          1         1                              Anderson, Mr. Harry
# ...      ...       ...                                              ...
# 1252       3         0                        Wittevrongel, Mr. Camille
# 1253       3         0                              Yasbeck, Mr. Antoni
# 1254       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1255       3         0                             Youseff, Mr. Gerious
# 1256       3         0                                Yousif, Mr. Wazli
#
#          sex   age  sibsp  parch      fare embarked
# ...

# %%
ship.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         0                     Allison, Miss. Helen Loraine  female
# 2       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 3       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 4       1         1                              Anderson, Mr. Harry    male
#
#     age  sibsp  parch      fare embarked
# 0  29.0      0      0  211.3375        S
# 1   2.0      1      2  151.5500        S
# 2  30.0      1      2  151.5500        S
# 3  25.0      1      2  151.5500        S
# 4  48.0      0      0   26.5500        S

# %%
ship.head(8)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         0                     Allison, Miss. Helen Loraine  female
# 2       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 3       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 4       1         1                              Anderson, Mr. Harry    male
# 5       1         0                           Andrews, Mr. Thomas Jr    male
# 6       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 7       1         0                           Astor, Col. John Jacob    male
#
#     age  sibsp  parch      fare embarked
# 0  29.0      0      0  211.3375        S
# 1   2.0      1      2  151.5500        S
# 2  30.0      1      2  151.5500        S
# 3  25.0      1      2  151.5500        S
# 4  48.0      0      0   26.5500        S
# ...

# %%
ship.tail()
# Out:
#       pclass  survived                                     name     sex   age  \
# 1252       3         0                Wittevrongel, Mr. Camille    male  36.0
# 1253       3         0                      Yasbeck, Mr. Antoni    male  27.0
# 1254       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1255       3         0                     Youseff, Mr. Gerious    male  45.5
# 1256       3         0                        Yousif, Mr. Wazli    male   NaN
#
#       sibsp  parch     fare embarked
# 1252      0      0   9.5000        S
# 1253      1      0  14.4542        C
# 1254      1      0  14.4542        C
# 1255      0      0   7.2250        C
# 1256      0      0   7.2250        C

# %%
ship.tail(10)
# Out:
#       pclass  survived                                     name     sex   age  \
# 1247       3         0        Williams, Mr. Howard Hugh "Harry"    male   NaN
# 1248       3         0                     Williams, Mr. Leslie    male  28.5
# 1249       3         0                      Windelov, Mr. Einar    male  21.0
# 1250       3         0                         Wirz, Mr. Albert    male  27.0
# 1251       3         0                   Wiseman, Mr. Phillippe    male   NaN
# 1252       3         0                Wittevrongel, Mr. Camille    male  36.0
# 1253       3         0                      Yasbeck, Mr. Antoni    male  27.0
# 1254       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1255       3         0                     Youseff, Mr. Gerious    male  45.5
# 1256       3         0                        Yousif, Mr. Wazli    male   NaN
#
#       sibsp  parch     fare embarked
# 1247      0      0   8.0500        S
# ...

# %%
ship.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1257 entries, 0 to 1256
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1257 non-null   int64
#  1   survived  1257 non-null   int64
#  2   name      1257 non-null   object
#  3   sex       1257 non-null   object
#  4   age       996 non-null    float64
#  5   sibsp     1257 non-null   int64
#  6   parch     1257 non-null   int64
#  7   fare      1257 non-null   float64
#  8   embarked  1257 non-null   object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 88.5+ KB

# %%
ship.describe()
# Out:
#             pclass     survived         age        sibsp        parch  \
# count  1257.000000  1257.000000  996.000000  1257.000000  1257.000000
# mean      2.310263     0.382657   29.070783     0.501989     0.377884
# std       0.831791     0.486229   12.819750     1.056616     0.863035
# min       1.000000     0.000000    1.000000     0.000000     0.000000
# 25%       2.000000     0.000000   21.000000     0.000000     0.000000
# 50%       3.000000     0.000000   28.000000     0.000000     0.000000
# 75%       3.000000     1.000000   37.000000     1.000000     0.000000
# max       3.000000     1.000000   60.000000     8.000000     9.000000
#
#               fare
# count  1257.000000
# mean     32.720896
# std      51.127788
# min       0.000000
# 25%       7.895800
# 50%      14.400000
# 75%      31.000000
# max     512.329200

# %%
ship.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked'],
#       dtype='object')

# %%
ship['embarked']
# Out:
# 0       S
# 1       S
# 2       S
# 3       S
# 4       S
#        ..
# 1252    S
# 1253    C
# 1254    C
# 1255    C
# 1256    C
# Name: embarked, Length: 1257, dtype: object

# %%
for i in ship.columns:
  print(i , ':', ship[i].unique())
# Out:
# pclass : [1 2 3]
# survived : [1 0]
# name : ['Allen, Miss. Elisabeth Walton' 'Allison, Miss. Helen Loraine'
#  'Allison, Mr. Hudson Joshua Creighton' ...
#  'Yasbeck, Mrs. Antoni (Selini Alexander)' 'Youseff, Mr. Gerious'
#  'Yousif, Mr. Wazli']
# sex : ['female' 'male']
# age : [29.   2.  30.  25.  48.  39.  53.  47.  18.  24.  26.   nan 50.  32.
#  36.  37.  42.  19.  35.  28.  45.  40.  58.  22.  41.  44.  59.  60.
#  33.  17.  11.  14.  49.  46.  27.  55.  38.  51.  31.   4.  54.  23.
#  43.  52.  16.  32.5 21.  15.  28.5 45.5 56.  13.  34.   6.  57.   1.
#  12.  20.   8.   7.   3.  36.5 18.5  5.   9.  22.5 40.5 10.  23.5 34.5
#  20.5 30.5 55.5 38.5 14.5 24.5 11.5]
# sibsp : [0 1 2 3 4 5 8]
# parch : [0 2 1 4 3 5 6 9]
# fare : [211.3375 151.55    26.55     0.      51.4792 227.525   69.3     78.85
#   25.925  247.5208  76.2917  75.2417  52.5542  30.     221.7792  26.
#   91.0792 135.6333  35.5     31.     164.8667 262.375   55.      30.5
# ...

# %%
ship['embarked'].value_counts()
# Out:
# embarked
# S    882
# C    256
# Q    119
# Name: count, dtype: int64

# %% [markdown]
# Create a dictionary, where the column name is the key & its index in the data is the value.
#
# col_indices = {'pclass':0, 'survived':1, 'name':2, 'sex':3, 'age':4, 'sibsp':5, 'parch':6, 'fare':7, 'embarked':8}

# %%
print(ship.columns)
print(list(range(len(ship.columns))))
for i in ship.columns:
  for j in range(len(ship.columns)):
    print(i, j)
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# pclass 0
# pclass 1
# pclass 2
# pclass 3
# pclass 4
# pclass 5
# pclass 6
# pclass 7
# pclass 8
# survived 0
# survived 1
# survived 2
# survived 3
# survived 4
# survived 5
# survived 6
# survived 7
# survived 8
# name 0
# name 1
# name 2
# name 3
# name 4
# name 5
# name 6
# name 7
# name 8
# sex 0
# sex 1
# sex 2
# sex 3
# sex 4
# sex 5
# sex 6
# sex 7
# sex 8
# age 0
# age 1
# age 2
# age 3
# age 4
# age 5
# age 6
# age 7
# age 8
# sibsp 0
# sibsp 1
# sibsp 2
# sibsp 3
# sibsp 4
# sibsp 5
# sibsp 6
# sibsp 7
# sibsp 8
# parch 0
# parch 1
# parch 2
# parch 3
# parch 4
# parch 5
# parch 6
# parch 7
# parch 8
# fare 0
# fare 1
# fare 2
# fare 3
# fare 4
# fare 5
# fare 6
# fare 7
# fare 8
# embarked 0
# embarked 1
# embarked 2
# embarked 3
# embarked 4
# embarked 5
# embarked 6
# embarked 7
# embarked 8

# %%
print(ship.columns)
print(list(range(len(ship.columns))))
for i,j in zip(ship.columns, range(len(ship.columns))):
  print(i, j)
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# pclass 0
# survived 1
# name 2
# sex 3
# age 4
# sibsp 5
# parch 6
# fare 7
# embarked 8

# %%
col_indices={}
for i,j in zip(ship.columns, range(len(ship.columns))):
  col_indices[i]=j
col_indices
# Out:
# {'pclass': 0,
#  'survived': 1,
#  'name': 2,
#  'sex': 3,
#  'age': 4,
#  'sibsp': 5,
#  'parch': 6,
#  'fare': 7,
#  'embarked': 8}

# %%
len(ship)
# Out:
# 1257

# %%
import numpy as np
ship.iloc[50:100, [2,8,4]]
# Out:
#                                                  name embarked   age
# 50                Carter, Master. William Thornton II        S  11.0
# 51                          Carter, Miss. Lucile Polk        S  14.0
# 52                         Carter, Mr. William Ernest        S  36.0
# 53          Carter, Mrs. William Ernest (Lucile Polk)        S  36.0
# 54                             Case, Mr. Howard Brown        S  49.0
# 55  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...        C   NaN
# 56                      Cavendish, Mr. Tyrell William        S  36.0
# 57                        Chaffee, Mr. Herbert Fuller        S  46.0
# 58  Chaffee, Mrs. Herbert Fuller (Carrie Constance...        S  47.0
# 59                      Chambers, Mr. Norman Campbell        S  27.0
# 60     Chambers, Mrs. Norman Campbell (Bertha Griggs)        S  33.0
# 61                        Chaudanson, Miss. Victorine        C  36.0
# 62                               Cherry, Miss. Gladys        S  30.0
# ...

# %%
ship.iloc[np.arange(0,len(ship),5), [2,8,4]]
# Out:
#                                                  name embarked   age
# 0                       Allen, Miss. Elisabeth Walton        S  29.0
# 5                              Andrews, Mr. Thomas Jr        S  39.0
# 10                       Barber, Miss. Ellen "Nellie"        S  26.0
# 15                               Beattie, Mr. Thomson        C  36.0
# 20                                  Bird, Miss. Ellen        S  29.0
# ...                                               ...      ...   ...
# 1235                             Waelens, Mr. Achille        S  22.0
# 1240  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)        C  38.0
# 1245                 Willer, Mr. Aaron ("Abi Weller")        S   NaN
# 1250                                 Wirz, Mr. Albert        S  27.0
# 1255                             Youseff, Mr. Gerious        C  45.5
#
# [252 rows x 3 columns]

# %%
ship.iloc[[5,10,15,20,25,30,35,40], [2,8,4]]
# Out:
#                                          name embarked   age
# 5                      Andrews, Mr. Thomas Jr        S  39.0
# 10               Barber, Miss. Ellen "Nellie"        S  26.0
# 15                       Beattie, Mr. Thomson        C  36.0
# 20                          Bird, Miss. Ellen        S  29.0
# 25  Bjornstrom-Steffansson, Mr. Mauritz Hakan        S  28.0
# 30                   Borebank, Mr. John James        S  42.0
# 35                         Brandeis, Mr. Emil        C  48.0
# 40            Burns, Miss. Elizabeth Margaret        C  41.0

# %%
ship.iloc[0:len(ship):5, [2,8,4]]
# Out:
#                                                  name embarked   age
# 0                       Allen, Miss. Elisabeth Walton        S  29.0
# 5                              Andrews, Mr. Thomas Jr        S  39.0
# 10                       Barber, Miss. Ellen "Nellie"        S  26.0
# 15                               Beattie, Mr. Thomson        C  36.0
# 20                                  Bird, Miss. Ellen        S  29.0
# ...                                               ...      ...   ...
# 1235                             Waelens, Mr. Achille        S  22.0
# 1240  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)        C  38.0
# 1245                 Willer, Mr. Aaron ("Abi Weller")        S   NaN
# 1250                                 Wirz, Mr. Albert        S  27.0
# 1255                             Youseff, Mr. Gerious        C  45.5
#
# [252 rows x 3 columns]

# %%
ship
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         0                     Allison, Miss. Helen Loraine
# 2          1         0             Allison, Mr. Hudson Joshua Creighton
# 3          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 4          1         1                              Anderson, Mr. Harry
# ...      ...       ...                                              ...
# 1252       3         0                        Wittevrongel, Mr. Camille
# 1253       3         0                              Yasbeck, Mr. Antoni
# 1254       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1255       3         0                             Youseff, Mr. Gerious
# 1256       3         0                                Yousif, Mr. Wazli
#
#          sex   age  sibsp  parch      fare embarked
# ...

# %%
ship.loc[[5,10,15,20,25,30,35,40], ['name','pclass','embarked']]
# Out:
#                                          name  pclass embarked
# 5                      Andrews, Mr. Thomas Jr       1        S
# 10               Barber, Miss. Ellen "Nellie"       1        S
# 15                       Beattie, Mr. Thomson       1        C
# 20                          Bird, Miss. Ellen       1        S
# 25  Bjornstrom-Steffansson, Mr. Mauritz Hakan       1        S
# 30                   Borebank, Mr. John James       1        S
# 35                         Brandeis, Mr. Emil       1        C
# 40            Burns, Miss. Elizabeth Margaret       1        C

# %%
ship.iloc[np.random.choice(len(ship), 100, replace=False), :]
# Out:
#       pclass  survived                                             name  \
# 526        2         1     Shelley, Mrs. William (Imanita Parrish Hall)
# 142        1         1                      Hawksford, Mr. Walter James
# 105        1         1                       Fortune, Miss. Mabel Helen
# 1113       3         0                       Rommetvedt, Mr. Knud Paust
# 157        1         1  Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)
# ...      ...       ...                                              ...
# 702        3         0                         Cribb, Mr. John Hatfield
# 126        1         1                        Gracie, Col. Archibald IV
# 517        2         0                               Richard, Mr. Emile
# 882        3         1         Kelly, Miss. Anna Katherine "Annie Kate"
# 56         1         0                    Cavendish, Mr. Tyrell William
#
#          sex   age  sibsp  parch      fare embarked
# ...

# %%
ship.groupby('pclass')['fare'].mean()
# Out:
# pclass
# 1    87.415153
# 2    21.337453
# 3    13.345681
# Name: fare, dtype: float64

# %%
ship.groupby('pclass')[['fare','age','survived']].mean()
# Out:
#              fare        age  survived
# pclass
# 1       87.415153  37.174330  0.640000
# 2       21.337453  29.139442  0.426966
# 3       13.345681  24.665289  0.253623

# %%
ship['pclass'].value_counts()
# Out:
# pclass
# 3    690
# 1    300
# 2    267
# Name: count, dtype: int64

# %%
ship.groupby('pclass')['survived'].sum()
# Out:
# pclass
# 1    192
# 2    114
# 3    175
# Name: survived, dtype: int64

# %%
ship['age']<5
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 1252    False
# 1253    False
# 1254    False
# 1255    False
# 1256    False
# Name: age, Length: 1257, dtype: bool

# %%
ship[ship['age']<5]
# Out:
#       pclass  survived                                      name     sex  age  \
# 1          1         0              Allison, Miss. Helen Loraine  female  2.0
# 86         1         1                 Dodge, Master. Washington    male  4.0
# 316        2         1                 Becker, Master. Richard F    male  1.0
# 317        2         1               Becker, Miss. Marion Louise  female  4.0
# 451        2         1                     Laroche, Miss. Louise  female  1.0
# 452        2         1  Laroche, Miss. Simonne Marie Anne Andree  female  3.0
# 464        2         1                     Mallet, Master. Andre    male  1.0
# 484        2         1            Navratil, Master. Edmond Roger    male  2.0
# 485        2         1                Navratil, Master. Michel M    male  3.0
# 510        2         1                  Quick, Miss. Phyllis May  female  2.0
# 518        2         1            Richards, Master. William Rowe    male  3.0
# ...

# %%
ship[ship['age']==1]
# Out:
#       pclass  survived                             name     sex  age  sibsp  \
# 316        2         1        Becker, Master. Richard F    male  1.0      2
# 451        2         1            Laroche, Miss. Louise  female  1.0      1
# 464        2         1            Mallet, Master. Andre    male  1.0      0
# 724        3         1       Dean, Master. Bertram Vere    male  1.0      1
# 786        3         0  Goodwin, Master. Sidney Leonard    male  1.0      5
# 855        3         1     Johnson, Miss. Eleanor Ileen  female  1.0      1
# 897        3         0     Klasen, Miss. Gertrud Emilia  female  1.0      1
# 1008       3         1      Nakid, Miss. Maria ("Mary")  female  1.0      0
# 1060       3         0     Panula, Master. Eino Viljami    male  1.0      4
# 1145       3         1  Sandstrom, Miss. Beatrice Irene  female  1.0      1
#
#       parch     fare embarked
# 316       1  39.0000        S
# 451       2  41.5792        C
# 464       2  37.0042        C
# ...

# %%
ship[(ship['age']==1) & (ship['sex']=='male')]
# Out:
#       pclass  survived                             name   sex  age  sibsp  \
# 316        2         1        Becker, Master. Richard F  male  1.0      2
# 464        2         1            Mallet, Master. Andre  male  1.0      0
# 724        3         1       Dean, Master. Bertram Vere  male  1.0      1
# 786        3         0  Goodwin, Master. Sidney Leonard  male  1.0      5
# 1060       3         0     Panula, Master. Eino Viljami  male  1.0      4
#
#       parch     fare embarked
# 316       1  39.0000        S
# 464       2  37.0042        C
# 724       2  20.5750        S
# 786       2  46.9000        S
# 1060      1  39.6875        S

# %%
males_aging_1 = ship[(ship['age']==1) & (ship['sex']=='male')]
males_aging_1
# Out:
#       pclass  survived                             name   sex  age  sibsp  \
# 316        2         1        Becker, Master. Richard F  male  1.0      2
# 464        2         1            Mallet, Master. Andre  male  1.0      0
# 724        3         1       Dean, Master. Bertram Vere  male  1.0      1
# 786        3         0  Goodwin, Master. Sidney Leonard  male  1.0      5
# 1060       3         0     Panula, Master. Eino Viljami  male  1.0      4
#
#       parch     fare embarked
# 316       1  39.0000        S
# 464       2  37.0042        C
# 724       2  20.5750        S
# 786       2  46.9000        S
# 1060      1  39.6875        S

# %%
males_aging_1.to_csv('/content/sample_data/males_aging_1')

# %%
ship[(ship['pclass']==1) & (ship['survived']==0) & (ship['age']<5)]
# Out:
#    pclass  survived                          name     sex  age  sibsp  parch  \
# 1       1         0  Allison, Miss. Helen Loraine  female  2.0      1      2
#
#      fare embarked
# 1  151.55        S

# %%
ship[(ship['pclass']==1) & (ship['survived']==0) & (ship['sex']=='female')]
# Out:
#      pclass  survived                                             name  \
# 1         1         0                     Allison, Miss. Helen Loraine
# 3         1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 97        1         0                         Evans, Miss. Edith Corse
# 158       1         0                       Isham, Miss. Ann Elizabeth
#
#         sex   age  sibsp  parch      fare embarked
# 1    female   2.0      1      2  151.5500        S
# 3    female  25.0      1      2  151.5500        S
# 97   female  36.0      0      0   31.6792        C
# 158  female  50.0      0      0   28.7125        C

# %%
ship[(ship['sibsp']==0) & (ship['parch']==0)]
# Out:
#       pclass  survived                           name     sex   age  sibsp  \
# 0          1         1  Allen, Miss. Elisabeth Walton  female  29.0      0
# 4          1         1            Anderson, Mr. Harry    male  48.0      0
# 5          1         0         Andrews, Mr. Thomas Jr    male  39.0      0
# 9          1         1  Aubart, Mme. Leontine Pauline  female  24.0      0
# 10         1         1   Barber, Miss. Ellen "Nellie"  female  26.0      0
# ...      ...       ...                            ...     ...   ...    ...
# 1250       3         0               Wirz, Mr. Albert    male  27.0      0
# 1251       3         0         Wiseman, Mr. Phillippe    male   NaN      0
# 1252       3         0      Wittevrongel, Mr. Camille    male  36.0      0
# 1255       3         0           Youseff, Mr. Gerious    male  45.5      0
# 1256       3         0              Yousif, Mr. Wazli    male   NaN      0
#
#       parch      fare embarked
# 0         0  211.3375        S
# ...

# %%
len(ship[(ship['sibsp']==0) & (ship['parch']==0)])
# Out:
# 764

# %%
ship[(ship['sibsp']==0) & (ship['parch']==0)].groupby('embarked')['age'].mean()
# Out:
# embarked
# C    33.282609
# Q    26.200000
# S    29.950913
# Name: age, dtype: float64

# %%
ship[(ship['sibsp']==0) & (ship['parch']==0)]['embarked'].value_counts()
# Out:
# embarked
# S    540
# C    130
# Q     94
# Name: count, dtype: int64

# %%
pd.crosstab(ship['embarked'], ship['survived'])
# Out:
# survived    0    1
# embarked
# C         110  146
# Q          75   44
# S         591  291

# %%
pd.crosstab(ship['embarked'], ship['pclass'])
# Out:
# pclass      1    2    3
# embarked
# C         135   28   93
# Q           3    5  111
# S         162  234  486

# %%
pd.crosstab(ship['embarked'], ship['pclass'], values=ship['fare'], aggfunc='mean')
# Out:
# pclass             1          2          3
# embarked
# C         107.394598  23.300593  10.842301
# Q          90.000000  12.021660  10.438403
# S          70.717748  21.301603  14.488731

# %%
ship[(ship['embarked']=='C') & (ship['pclass']==1)]['fare'].mean()
# Out:
# 107.39459777777779

# %%
pd.crosstab(ship['embarked'], ship['pclass'], values=ship['fare'], aggfunc='max')
# Out:
# pclass           1        2        3
# embarked
# C         512.3292  41.5792  22.3583
# Q          90.0000  12.3500  29.1250
# S         263.0000  73.5000  69.5500

# %%
pd.crosstab(ship['embarked'], ship['pclass'], values=ship['fare'], aggfunc='min')
# Out:
# pclass          1        2       3
# embarked
# C         25.7417  12.0000  4.0125
# Q         90.0000  10.7083  6.7500
# S          0.0000   0.0000  0.0000

# %%
min(ship['fare'])
# Out:
# 0.0

# %%
pd.crosstab(ship['embarked'], ship['pclass'], values=ship['age'], aggfunc='max')
# Out:
# pclass       1     2     3
# embarked
# C         60.0  41.0  45.5
# Q         44.0  57.0  40.5
# S         60.0  60.0  59.0

# %%
ship[ship['age']==60].loc[:,['name','pclass','embarked']]
# Out:
#                                                  name  pclass embarked
# 39    Bucknell, Mrs. William Robert (Emma Eliza Ward)       1        C
# 107               Fortune, Mrs. Mark (Mary McDougald)       1        S
# 114                  Frolicher-Stehli, Mr. Maxmillian       1        C
# 282  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)       1        C
# 283                                   Weir, Col. John       1        S
# 328                 Brown, Mr. Thomas William Solomon       2        S
# 429      Howard, Mrs. Benjamin (Ellen Truelove Arman)       2        S

# %%
df = pd.DataFrame()
df['Course'] =['Data Science', 'Data Analytics', 'Artificial Intelligence', 'Full Stack Development']
df['Duration'] = ['3 Months', '4 Months', '4 Months', '6 Months']
df['Trainer'] = ['Neha', 'Multiple Trainers', 'Varun', 'Aishwarya']
df['Classroom'] = ['Newton', 'Aryabhatta', 'Tesla', 'Darwin']
df
# Out:
#                     Course  Duration            Trainer   Classroom
# 0             Data Science  3 Months               Neha      Newton
# 1           Data Analytics  4 Months  Multiple Trainers  Aryabhatta
# 2  Artificial Intelligence  4 Months              Varun       Tesla
# 3   Full Stack Development  6 Months          Aishwarya      Darwin

# %%
df.rename({'Course': 'Course Name'}, inplace = True, axis=1)

# %%
df.rename({'Trainer': 'Instructor'}, inplace = True, axis=1)
df
# Out:
#                     Course  Duration         Instructor   Classroom
# 0             Data Science  3 Months               Neha      Newton
# 1           Data Analytics  4 Months  Multiple Trainers  Aryabhatta
# 2  Artificial Intelligence  4 Months              Varun       Tesla
# 3   Full Stack Development  6 Months          Aishwarya      Darwin

# %%
df.drop('Instructor', axis=1)
# Out:
#                     Course  Duration   Classroom
# 0             Data Science  3 Months      Newton
# 1           Data Analytics  4 Months  Aryabhatta
# 2  Artificial Intelligence  4 Months       Tesla
# 3   Full Stack Development  6 Months      Darwin

# %%
df.drop('Instructor', axis=1, inplace=True)
df
# Out:
#                     Course  Duration   Classroom
# 0             Data Science  3 Months      Newton
# 1           Data Analytics  4 Months  Aryabhatta
# 2  Artificial Intelligence  4 Months       Tesla
# 3   Full Stack Development  6 Months      Darwin

# %%
df = df.transpose()
df
# Out:
#                       0               1                        2  \
# Course     Data Science  Data Analytics  Artificial Intelligence
# Duration       3 Months        4 Months                 4 Months
# Classroom        Newton      Aryabhatta                    Tesla
#
#                                 3
# Course     Full Stack Development
# Duration                 6 Months
# Classroom                  Darwin

# %%
df.rename({'Classroom':'Location'}, axis=0, inplace=True)
df
# Out:
#                      0               1                        2  \
# Course    Data Science  Data Analytics  Artificial Intelligence
# Duration      3 Months        4 Months                 4 Months
# Location        Newton      Aryabhatta                    Tesla
#
#                                3
# Course    Full Stack Development
# Duration                6 Months
# Location                  Darwin

# %%
df = pd.DataFrame()
df['Course'] =['Data Science', 'Data Analytics', 'Artificial Intelligence', 'Full Stack Development']
df['Duration'] = ['3 Months', '4 Months', '4 Months', '6 Months']
df['Trainer'] = ['Neha', 'Multiple Trainers', 'Varun', 'Aishwarya']
df['Classroom'] = ['Newton', 'Aryabhatta', 'Tesla', 'Darwin']
df
# Out:
#                     Course  Duration            Trainer   Classroom
# 0             Data Science  3 Months               Neha      Newton
# 1           Data Analytics  4 Months  Multiple Trainers  Aryabhatta
# 2  Artificial Intelligence  4 Months              Varun       Tesla
# 3   Full Stack Development  6 Months          Aishwarya      Darwin

# %%
df['Duration'].replace({'6 Months': '5 Months'}, inplace = True)
df
# Out:
#                     Course  Duration            Trainer   Classroom
# 0             Data Science  3 Months               Neha      Newton
# 1           Data Analytics  4 Months  Multiple Trainers  Aryabhatta
# 2  Artificial Intelligence  4 Months              Varun       Tesla
# 3   Full Stack Development  5 Months          Aishwarya      Darwin

# %% [markdown]
# In Duration column, replace '3 Months' to '2.5 Months', & in Trainer column, replace 'Multiple Trainers' with 'Dharmendra'

# %%
#df.replace({'3 Months':'2.5 Months', 'Multiple Trainers':'Dharmendra'}, inplace = True)
#df
df.replace({'Duration': {'2.5 Months':'3 Months'},'Trainer': {'Dharmendra':'Ritika', 'Aishwarya': 'Priyanka'}},
           inplace = True)
df
# Out:
#                     Course  Duration   Trainer   Classroom
# 0             Data Science  3 Months      Neha      Newton
# 1           Data Analytics  4 Months    Ritika  Aryabhatta
# 2  Artificial Intelligence  4 Months     Varun       Tesla
# 3   Full Stack Development  5 Months  Priyanka      Darwin

# %%
df = pd.DataFrame()
df['Course'] =['Data Science', 'Data Analytics', 'Artificial Intelligence', 'Full Stack Development']
df['Duration'] = ['3 Months', '4 Months', '4 Months', '6 Months']
df['Trainer'] = ['Neha', 'Multiple Trainers', 'Varun', 'Aishwarya']
df['Classroom'] = ['Newton', 'Aryabhatta', 'Tesla', 'Darwin']
print(df)
df.iloc[2,1]='3.5 Months'
df
# Out:
#                     Course  Duration            Trainer   Classroom
# 0             Data Science  3 Months               Neha      Newton
# 1           Data Analytics  4 Months  Multiple Trainers  Aryabhatta
# 2  Artificial Intelligence  4 Months              Varun       Tesla
# 3   Full Stack Development  6 Months          Aishwarya      Darwin

# %%
import numpy as np
Marks = pd.DataFrame()
Marks['Name'] = ['Pradeep', 'Rahul', 'Alex','Mithun', 'Chandu', 'Pranav']
Marks['Maths'] = np.random.randint(0,100, 6)
Marks['History'] = np.random.randint(0,100, 6)
Marks['Science'] = np.random.randint(0,100, 6)
Marks['English'] = np.random.randint(0,100, 6)
Marks
# Out:
#       Name  Maths  History  Science  English
# 0  Pradeep      8       43       97       49
# 1    Rahul     70       66       17       96
# 2     Alex     57       23       75       14
# 3   Mithun     83       26       21       77
# 4   Chandu     87        7       84       49
# 5   Pranav      6       73       63        1

# %%
Marks.loc[3.5] = ['Neha',97,74,85,65]
Marks=Marks.sort_index().reset_index(drop=True)
Marks
# Out:
#       Name  Maths  History  Science  English
# 0  Pradeep      8       43       97       49
# 1    Rahul     70       66       17       96
# 2     Alex     57       23       75       14
# 3   Mithun     83       26       21       77
# 4     Neha     97       74       85       65
# 5   Chandu     87        7       84       49
# 6   Pranav      6       73       63        1

# %%
Marks.loc[3.5] = ['Srikanth', 85, 96, 78, 86]
Marks.sort_index(inplace=True)
print(Marks)
Marks.reset_index(drop=True,inplace=True)
Marks
# Out:
#          Name  Maths  History  Science  English
# 0.0   Pradeep      8       43       97       49
# 1.0     Rahul     70       66       17       96
# 2.0      Alex     57       23       75       14
# 3.0    Mithun     83       26       21       77
# 3.5  Srikanth     85       96       78       86
# 4.0      Neha     97       74       85       65
# 5.0    Chandu     87        7       84       49
# 6.0    Pranav      6       73       63        1
#        Name  Maths  History  Science  English
# 0   Pradeep      8       43       97       49
# 1     Rahul     70       66       17       96
# 2      Alex     57       23       75       14
# 3    Mithun     83       26       21       77
# 4  Srikanth     85       96       78       86
# 5      Neha     97       74       85       65
# 6    Chandu     87        7       84       49
# 7    Pranav      6       73       63        1

# %%
Srikanth = pd.DataFrame({'Name':'Srikanth', 'Maths':[85], 'History':[96], 'Science':[78], 'English': [86]})
print(Srikanth)
Marks=pd.concat([Marks.iloc[:4,:],Srikanth,Marks.iloc[4:,:]]).reset_index(drop=True)
Marks
# Out:
#        Name  Maths  History  Science  English
# 0  Srikanth     85       96       78       86
#        Name  Maths  History  Science  English
# 0   Pradeep     49       64       71       11
# 1     Rahul     59       41       76        3
# 2      Alex      0       95       50       61
# 3    Mithun     20       57       28        4
# 4  Srikanth     85       96       78       86
# 5    Chandu     44       89       52       59
# 6    Pranav     91       90       59       80

# %%
import numpy as np
Marks = pd.DataFrame()
Marks['Name'] = ['Pradeep', 'Rahul', 'Alex','Mithun', 'Chandu', 'Pranav']
Marks['Maths'] = np.random.randint(0,100, 6)
Marks['History'] = np.random.randint(0,100, 6)
Marks['Science'] = np.random.randint(0,100, 6)
Marks['English'] = np.random.randint(0,100, 6)
Marks['Index'] = ['A','B','C','D','E','F']
Marks.set_index('Index', inplace=True)
Marks
# Out:
#           Name  Maths  History  Science  English
# Index
# A      Pradeep     36       39       99       95
# B        Rahul     77       85       16       18
# C         Alex     46       71       29       31
# D       Mithun     51       47       53       27
# E       Chandu     97        6       37       29
# F       Pranav     83       99       69       11

# %%
Marks.loc[['B','E'], ['Maths','Science']]
# Out:
#        Maths  Science
# Index
# B         77       16
# E         97       37

# %%
Marks.iloc[[1,4],[1,3]]
# Out:
#        Maths  Science
# Index
# B         77       16
# E         97       37

# %%
Marks = pd.DataFrame()
Marks['Name'] = ['Pradeep', 'Rahul', 'Alex','Mithun', 'Chandu', 'Pranav']
Marks['Maths'] = np.random.randint(0,100, 6)
Marks['History'] = np.random.randint(0,100, 6)
Marks['Science'] = np.random.randint(0,100, 6)
Marks['English'] = np.random.randint(0,100, 6)
Marks.loc[3.5] = ['Neha',97,74,85,65]
Marks=Marks.sort_index().reset_index()
Marks
# Out:
#    index     Name  Maths  History  Science  English
# 0    0.0  Pradeep     93       44        3       84
# 1    1.0    Rahul     93       64       26       66
# 2    2.0     Alex     90        6       46       16
# 3    3.0   Mithun     75       37        1       38
# 4    3.5     Neha     97       74       85       65
# 5    4.0   Chandu     93       19       41       25
# 6    5.0   Pranav     25       69       34       36

# %%
Marks = pd.DataFrame()
Marks['Name'] = ['Pradeep', 'Rahul', 'Alex','Mithun', 'Chandu', 'Pranav']
Marks['Maths'] = np.random.randint(0,100, 6)
Marks['History'] = np.random.randint(0,100, 6)
Marks['Science'] = np.random.randint(0,100, 6)
Marks['English'] = np.random.randint(0,100, 6)
Marks

#Add Geography column after history with the following marks : [52,74,12,45,96,36]
Marks.insert(3, value=[52,74,12,45,96,36],column='Geography')
Marks
# Out:
#       Name  Maths  History  Geography  Science  English
# 0  Pradeep     17       72         52       45       37
# 1    Rahul     13       28         74       56       17
# 2     Alex     28       33         12       76       17
# 3   Mithun     62       29         45        7       24
# 4   Chandu     36       56         96       97       55
# 5   Pranav     44       11         36       41        9
