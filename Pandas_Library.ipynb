# %%
import pandas as pd
from google.colab import files
ship=files.upload()
# Out:
#      <input type="file" id="files-47ea2cfe-597a-4eb4-9c3b-825652f107bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-47ea2cfe-597a-4eb4-9c3b-825652f107bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ship = pd.read_csv('titanic.csv')
ship
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         0                     Allison, Miss. Helen Loraine
# 2          1         0             Allison, Mr. Hudson Joshua Creighton
# 3          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 4          1         1                              Anderson, Mr. Harry
# ...      ...       ...                                              ...
# 1252       3         0                        Wittevrongel, Mr. Camille
# 1253       3         0                              Yasbeck, Mr. Antoni
# 1254       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1255       3         0                             Youseff, Mr. Gerious
# 1256       3         0                                Yousif, Mr. Wazli
#
#          sex   age  sibsp  parch      fare embarked
# ...

# %%
from google.colab import files
store=files.upload()
# Out:
#      <input type="file" id="files-2de074c4-ab30-4d37-8fed-a572e1fa5cb7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2de074c4-ab30-4d37-8fed-a572e1fa5cb7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
store = pd.read_excel('Sample - Superstore.xls', sheet_name='Orders')
store
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2020-103800 2020-01-03 2020-01-07  Standard Class
# 1           2  US-2020-112326 2020-01-04 2020-01-08  Standard Class
# 2           3  US-2020-112326 2020-01-04 2020-01-08  Standard Class
# 3           4  US-2020-112326 2020-01-04 2020-01-08  Standard Class
# 4           5  US-2020-141817 2020-01-05 2020-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2023-143259 2023-12-30 2024-01-03  Standard Class
# 10190   10191  US-2023-115427 2023-12-30 2024-01-03  Standard Class
# 10191   10192  US-2023-156720 2023-12-30 2024-01-03  Standard Class
# 10192   10193  US-2023-143259 2023-12-30 2024-01-03  Standard Class
# 10193   10194  CA-2023-143500 2023-12-30 2024-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
#By default head method will show the top 5 rows of the dataframe.
#If we mention an integer value 'n' inside head method, then it will show n top rows of the data.
ship.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         0                     Allison, Miss. Helen Loraine  female
# 2       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 3       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 4       1         1                              Anderson, Mr. Harry    male
#
#     age  sibsp  parch      fare embarked
# 0  29.0      0      0  211.3375        S
# 1   2.0      1      2  151.5500        S
# 2  30.0      1      2  151.5500        S
# 3  25.0      1      2  151.5500        S
# 4  48.0      0      0   26.5500        S

# %%
ship.head(8)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         0                     Allison, Miss. Helen Loraine  female
# 2       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 3       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 4       1         1                              Anderson, Mr. Harry    male
# 5       1         0                           Andrews, Mr. Thomas Jr    male
# 6       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 7       1         0                           Astor, Col. John Jacob    male
#
#     age  sibsp  parch      fare embarked
# 0  29.0      0      0  211.3375        S
# 1   2.0      1      2  151.5500        S
# 2  30.0      1      2  151.5500        S
# 3  25.0      1      2  151.5500        S
# 4  48.0      0      0   26.5500        S
# ...

# %%
#By default tail method will show the bottom most 5 rows of the dataframe.
#If we mention an integer value 'n' inside tail method, then it will show n bottom most rows of the data.
ship.tail()
# Out:
#       pclass  survived                                     name     sex   age  \
# 1252       3         0                Wittevrongel, Mr. Camille    male  36.0
# 1253       3         0                      Yasbeck, Mr. Antoni    male  27.0
# 1254       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1255       3         0                     Youseff, Mr. Gerious    male  45.5
# 1256       3         0                        Yousif, Mr. Wazli    male   NaN
#
#       sibsp  parch     fare embarked
# 1252      0      0   9.5000        S
# 1253      1      0  14.4542        C
# 1254      1      0  14.4542        C
# 1255      0      0   7.2250        C
# 1256      0      0   7.2250        C

# %%
ship.tail(10)
# Out:
#       pclass  survived                                     name     sex   age  \
# 1247       3         0        Williams, Mr. Howard Hugh "Harry"    male   NaN
# 1248       3         0                     Williams, Mr. Leslie    male  28.5
# 1249       3         0                      Windelov, Mr. Einar    male  21.0
# 1250       3         0                         Wirz, Mr. Albert    male  27.0
# 1251       3         0                   Wiseman, Mr. Phillippe    male   NaN
# 1252       3         0                Wittevrongel, Mr. Camille    male  36.0
# 1253       3         0                      Yasbeck, Mr. Antoni    male  27.0
# 1254       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1255       3         0                     Youseff, Mr. Gerious    male  45.5
# 1256       3         0                        Yousif, Mr. Wazli    male   NaN
#
#       sibsp  parch     fare embarked
# 1247      0      0   8.0500        S
# ...

# %%
ship.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1257 entries, 0 to 1256
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1257 non-null   int64
#  1   survived  1257 non-null   int64
#  2   name      1257 non-null   object
#  3   sex       1257 non-null   object
#  4   age       996 non-null    float64
#  5   sibsp     1257 non-null   int64
#  6   parch     1257 non-null   int64
#  7   fare      1257 non-null   float64
#  8   embarked  1257 non-null   object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 88.5+ KB

# %%
1257-996
# Out:
# 261

# %%
ship.describe()
# Out:
#             pclass     survived         age        sibsp        parch  \
# count  1257.000000  1257.000000  996.000000  1257.000000  1257.000000
# mean      2.310263     0.382657   29.070783     0.501989     0.377884
# std       0.831791     0.486229   12.819750     1.056616     0.863035
# min       1.000000     0.000000    1.000000     0.000000     0.000000
# 25%       2.000000     0.000000   21.000000     0.000000     0.000000
# 50%       3.000000     0.000000   28.000000     0.000000     0.000000
# 75%       3.000000     1.000000   37.000000     1.000000     0.000000
# max       3.000000     1.000000   60.000000     8.000000     9.000000
#
#               fare
# count  1257.000000
# mean     32.720896
# std      51.127788
# min       0.000000
# 25%       7.895800
# 50%      14.400000
# 75%      31.000000
# max     512.329200

# %%
ship[0:3]
# Out:
#    pclass  survived                                  name     sex   age  \
# 0       1         1         Allen, Miss. Elisabeth Walton  female  29.0
# 1       1         0          Allison, Miss. Helen Loraine  female   2.0
# 2       1         0  Allison, Mr. Hudson Joshua Creighton    male  30.0
#
#    sibsp  parch      fare embarked
# 0      0      0  211.3375        S
# 1      1      2  151.5500        S
# 2      1      2  151.5500        S

# %%
ship.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked'],
#       dtype='object')

# %% [markdown]
# Create a dictionary, where the column name, is the key, and the respective column index is the value
#
# Expected Output:
#
# col_indices = {'pclass': 0, 'survived':1, 'name':2, 'sex':3, 'age':4, 'sibsp':5, 'parch':6, 'fare':7,
#        'embarked':8}

# %%
list1 = ['a','b','c','d','e']
list2 = [1,2,3,4,5]
for i in list1:
  for j in list2:
    print(i,j)
# Out:
# a 1
# a 2
# a 3
# a 4
# a 5
# b 1
# b 2
# b 3
# b 4
# b 5
# c 1
# c 2
# c 3
# c 4
# c 5
# d 1
# d 2
# d 3
# d 4
# d 5
# e 1
# e 2
# e 3
# e 4
# e 5

# %%
for i,j in zip(list1,list2):
  print(i,j)
# Out:
# a 1
# b 2
# c 3
# d 4
# e 5

# %%
print(ship.columns)
print(list(range(len(ship.columns))))
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
col_indices = {}
for i in ship.columns:
  for j in range(len(ship.columns)):
    col_indices[i] = j
col_indices
# Out:
# {'pclass': 8,
#  'survived': 8,
#  'name': 8,
#  'sex': 8,
#  'age': 8,
#  'sibsp': 8,
#  'parch': 8,
#  'fare': 8,
#  'embarked': 8}

# %%
col_indices = {}
for i,j in zip(ship.columns,range(len(ship.columns))):
    col_indices[i] = j
col_indices
# Out:
# ['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked']
# {'pclass': 0,
#  'survived': 1,
#  'name': 2,
#  'sex': 3,
#  'age': 4,
#  'sibsp': 5,
#  'parch': 6,
#  'fare': 7,
#  'embarked': 8}

# %%
col_indices = {}
for i in range(len(ship.columns)):    #i = 0,1,2,3...8
    col_indices[ship.columns[i]] = i
col_indices
# Out:
# {'pclass': 0,
#  'survived': 1,
#  'name': 2,
#  'sex': 3,
#  'age': 4,
#  'sibsp': 5,
#  'parch': 6,
#  'fare': 7,
#  'embarked': 8}

# %%
#To display rows from index 20 to 24, & columns at index 2,4,1
ship.iloc[20:25, [2,4,1]]
# Out:
#                                        name   age  survived
# 20                        Bird, Miss. Ellen  29.0         1
# 21                      Birnbaum, Mr. Jakob  25.0         0
# 22                  Bishop, Mr. Dickinson H  25.0         1
# 23  Bishop, Mrs. Dickinson H (Helen Walton)  19.0         1
# 24                   Bissette, Miss. Amelia  35.0         1

# %%
ship.iloc[20:25, :]
# Out:
#     pclass  survived                                     name     sex   age  \
# 20       1         1                        Bird, Miss. Ellen  female  29.0
# 21       1         0                      Birnbaum, Mr. Jakob    male  25.0
# 22       1         1                  Bishop, Mr. Dickinson H    male  25.0
# 23       1         1  Bishop, Mrs. Dickinson H (Helen Walton)  female  19.0
# 24       1         1                   Bissette, Miss. Amelia  female  35.0
#
#     sibsp  parch      fare embarked
# 20      0      0  221.7792        S
# 21      0      0   26.0000        C
# 22      1      0   91.0792        C
# 23      1      0   91.0792        C
# 24      0      0  135.6333        S

# %%
ship.iloc[:, [2,7,8]]
# Out:
#                                                  name      fare embarked
# 0                       Allen, Miss. Elisabeth Walton  211.3375        S
# 1                        Allison, Miss. Helen Loraine  151.5500        S
# 2                Allison, Mr. Hudson Joshua Creighton  151.5500        S
# 3     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  151.5500        S
# 4                                 Anderson, Mr. Harry   26.5500        S
# ...                                               ...       ...      ...
# 1252                        Wittevrongel, Mr. Camille    9.5000        S
# 1253                              Yasbeck, Mr. Antoni   14.4542        C
# 1254          Yasbeck, Mrs. Antoni (Selini Alexander)   14.4542        C
# 1255                             Youseff, Mr. Gerious    7.2250        C
# 1256                                Yousif, Mr. Wazli    7.2250        C
#
# [1257 rows x 3 columns]

# %%
import numpy as np
ship.loc[np.arange(0,len(ship),5), ['name', 'sibsp', 'parch']]
# Out:
#                                                  name  sibsp  parch
# 0                       Allen, Miss. Elisabeth Walton      0      0
# 5                              Andrews, Mr. Thomas Jr      0      0
# 10                       Barber, Miss. Ellen "Nellie"      0      0
# 15                               Beattie, Mr. Thomson      0      0
# 20                                  Bird, Miss. Ellen      0      0
# ...                                               ...    ...    ...
# 1235                             Waelens, Mr. Achille      0      0
# 1240  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)      0      0
# 1245                 Willer, Mr. Aaron ("Abi Weller")      0      0
# 1250                                 Wirz, Mr. Albert      0      0
# 1255                             Youseff, Mr. Gerious      0      0
#
# [252 rows x 3 columns]

# %%
ship.loc[np.random.choice(len(ship),100, replace=False), ['name', 'sibsp', 'parch']]
# Out:
#                                                    name  sibsp  parch
# 357               Corbett, Mrs. Walter H (Irene Colvin)      0      0
# 1073                                 Pedersen, Mr. Olaf      0      0
# 969                                 McMahon, Mr. Martin      0      0
# 1066                                   Pasic, Mr. Jakob      0      0
# 77    Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
# ...                                                 ...    ...    ...
# 738                          Dorking, Mr. Edward Arthur      0      0
# 686                                   Coleff, Mr. Satio      0      0
# 214          Penasco y Castellana, Mr. Victor de Satode      1      0
# 55    Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...      0      0
# 784                     Goncalves, Mr. Manuel Estanslas      0      0
#
# [100 rows x 3 columns]

# %%
ship['pclass'].unique()
# Out:
# array([1, 2, 3])

# %%
ship['pclass'].value_counts()
# Out:
# pclass
# 3    690
# 1    300
# 2    267
# Name: count, dtype: int64

# %%
pd.crosstab(ship['pclass'], ship['survived'])
# Out:
# survived    0    1
# pclass
# 1         108  192
# 2         153  114
# 3         515  175

# %%
ship['embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
pd.crosstab(ship['pclass'],ship['embarked'], values = ship['fare'], aggfunc='mean')
# Out:
# embarked           C          Q          S
# pclass
# 1         107.394598  90.000000  70.717748
# 2          23.300593  12.021660  21.301603
# 3          10.842301  10.438403  14.488731

# %%
ship[ship['age'] < 10]
# Out:
#       pclass  survived                             name     sex  age  sibsp  \
# 1          1         0     Allison, Miss. Helen Loraine  female  2.0      1
# 86         1         1        Dodge, Master. Washington    male  4.0      0
# 258        1         1  Spedden, Master. Robert Douglas    male  6.0      0
# 316        2         1        Becker, Master. Richard F    male  1.0      2
# 317        2         1      Becker, Miss. Marion Louise  female  4.0      2
# ...      ...       ...                              ...     ...  ...    ...
# 1166       3         0               Skoog, Miss. Mabel  female  9.0      3
# 1167       3         0    Skoog, Miss. Margit Elizabeth  female  2.0      3
# 1187       3         0       Strom, Miss. Telma Matilda  female  2.0      0
# 1211       3         1   Touma, Master. Georges Youssef    male  7.0      1
# 1212       3         1       Touma, Miss. Maria Youssef  female  9.0      1
#
#       parch      fare embarked
# ...

# %%
ship[(ship['age'] == 1) & (ship['sex']=='male')]
# Out:
#       pclass  survived                             name   sex  age  sibsp  \
# 316        2         1        Becker, Master. Richard F  male  1.0      2
# 464        2         1            Mallet, Master. Andre  male  1.0      0
# 724        3         1       Dean, Master. Bertram Vere  male  1.0      1
# 786        3         0  Goodwin, Master. Sidney Leonard  male  1.0      5
# 1060       3         0     Panula, Master. Eino Viljami  male  1.0      4
#
#       parch     fare embarked
# 316       1  39.0000        S
# 464       2  37.0042        C
# 724       2  20.5750        S
# 786       2  46.9000        S
# 1060      1  39.6875        S

# %%
len(ship[(ship['age'] < 10) & (ship['survived']==1)])
# Out:
# 40

# %%
len(ship[(ship['sex'] == 'female') & (ship['survived']==1)])
# Out:
# 328

# %%
len(ship[(ship['age'] < 10) & (ship['survived']==0)])
# Out:
# 30

# %%
len(ship[(ship['sex'] == 'female') & (ship['survived']==0)])
# Out:
# 124

# %%
ship[(ship['parch'] == 0) & (ship['sibsp']==0)]
# Out:
#       pclass  survived                           name     sex   age  sibsp  \
# 0          1         1  Allen, Miss. Elisabeth Walton  female  29.0      0
# 4          1         1            Anderson, Mr. Harry    male  48.0      0
# 5          1         0         Andrews, Mr. Thomas Jr    male  39.0      0
# 9          1         1  Aubart, Mme. Leontine Pauline  female  24.0      0
# 10         1         1   Barber, Miss. Ellen "Nellie"  female  26.0      0
# ...      ...       ...                            ...     ...   ...    ...
# 1250       3         0               Wirz, Mr. Albert    male  27.0      0
# 1251       3         0         Wiseman, Mr. Phillippe    male   NaN      0
# 1252       3         0      Wittevrongel, Mr. Camille    male  36.0      0
# 1255       3         0           Youseff, Mr. Gerious    male  45.5      0
# 1256       3         0              Yousif, Mr. Wazli    male   NaN      0
#
#       parch      fare embarked
# 0         0  211.3375        S
# ...

# %%
ship[(ship['parch'] == 0) & (ship['sibsp']==0) & (ship['sex']=='female')]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 9          1         1                    Aubart, Mme. Leontine Pauline
# 10         1         1                     Barber, Miss. Ellen "Nellie"
# 14         1         1                            Bazzani, Miss. Albina
# 19         1         1                            Bidois, Miss. Rosalie
# ...      ...       ...                                              ...
# 1181       3         1                  Stanley, Miss. Amy Zillah Elsie
# 1184       3         0                      Strandberg, Miss. Ida Sofia
# 1215       3         1                          Turja, Miss. Anna Sofia
# 1233       3         0             Vestrom, Miss. Hulda Amanda Adolfina
# 1240       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
#
#          sex   age  sibsp  parch      fare embarked
# ...

# %%
ship.groupby(['pclass','age'])['fare'].mean()
# Out:
# pclass  age
# 1       2.0     151.550000
#         4.0      81.858300
#         6.0     134.500000
#         11.0    120.000000
#         13.0    262.375000
#                    ...
# 3       49.0      0.000000
#         50.0     11.275000
#         51.0      7.618067
#         55.5      8.050000
#         59.0      7.250000
# Name: fare, Length: 178, dtype: float64

# %%
ship[(ship['parch'] == 0) & (ship['sibsp']==0)].groupby('embarked').count()
# Out:
#           pclass  survived  name  sex  age  sibsp  parch  fare
# embarked
# C            130       130   130  130   92    130    130   130
# Q             94        94    94   94   35     94     94    94
# S            540       540   540  540  438    540    540   540

# %%
ship
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         0                     Allison, Miss. Helen Loraine
# 2          1         0             Allison, Mr. Hudson Joshua Creighton
# 3          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 4          1         1                              Anderson, Mr. Harry
# ...      ...       ...                                              ...
# 1252       3         0                        Wittevrongel, Mr. Camille
# 1253       3         0                              Yasbeck, Mr. Antoni
# 1254       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1255       3         0                             Youseff, Mr. Gerious
# 1256       3         0                                Yousif, Mr. Wazli
#
#          sex   age  sibsp  parch      fare embarked
# ...

# %%
ship.loc[ship['name'].str.contains('Jack', case=False)]
# Out:
#     pclass  survived                       name   sex  age  sibsp  parch  \
# 36       1         0  Brewe, Dr. Arthur Jackson  male  NaN      0      0
#
#     fare embarked
# 36  39.6        C

# %%
food = pd.DataFrame()
food['Fruits'] = ['Banana', 'Plum', 'Mango']
food['Vegetables'] = ['Potato', 'Onion', 'Peas']
food['Grains'] = ['Rice', 'Wheat', 'Daal']
food['Snacks'] = ['Samosa', 'Pizza', 'Burger']
food
# Out:
#    Fruits Vegetables Grains  Snacks
# 0  Banana     Potato   Rice  Samosa
# 1    Plum      Onion  Wheat   Pizza
# 2   Mango       Peas   Daal  Burger

# %%
food.drop('Snacks', axis=1)
# Out:
#    Fruits Vegetables Grains
# 0  Banana     Potato   Rice
# 1    Plum      Onion  Wheat
# 2   Mango       Peas   Daal

# %%
food
# Out:
#    Fruits Vegetables Grains  Snacks
# 0  Banana     Potato   Rice  Samosa
# 1    Plum      Onion  Wheat   Pizza
# 2   Mango       Peas   Daal  Burger

# %%
food.drop('Snacks', axis=1, inplace=True)
food
# Out:
#    Fruits Vegetables Grains
# 0  Banana     Potato   Rice
# 1    Plum      Onion  Wheat
# 2   Mango       Peas   Daal

# %%
food['Fruits'].replace({'Banana': 'Apple'}, inplace=True)
food
# Out:
#   Fruits Vegetables Grains
# 0  Apple     Potato   Rice
# 1   Plum      Onion  Wheat
# 2  Mango       Peas   Daal

# %% [markdown]
# 1. Change:
# - 'Apple' to 'Orange'
# - 'Plum' to 'Grapes'
# - 'Peas' to 'Carrot'
# - 'Daal' to 'Ragi',
# all in one command
#
#
# 2. Insert a new row at the index 1 as follows: 'Papaya', 'Cabbage', 'Horse Gram'
#
# 3. Insert a column at index 1 by the name 'Beverages', and enter values as follows: 'Tea', 'Coffee', 'Juice', 'Boost'
#
# 4. In the titanic dataset, find which row has the character 'Jack' & 'Rose'
