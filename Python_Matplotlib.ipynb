# %%
#Import pandas library.
import pandas as pd

# %%
#read.csv file...
df = pd.read_csv('DataSalary.csv')
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
# ...

# %%
#to print number of rows and columns.
df.shape
# Out:
# (3761, 9)

# %%
#to get column names.
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
df['job_title'].value_counts()
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
# ...

# %%
df[(df['work_year']==2023) & (df["job_title"]=="Applied Scientist")]
# Out:
#       work_year experience_level employment_type          job_title  salary  \
# 0          2023               EN              FT  Applied Scientist  213660
# 1          2023               EN              FT  Applied Scientist  130760
# 4          2023               EN              FT  Applied Scientist  204620
# 5          2023               EN              FT  Applied Scientist  110680
# 24         2023               EN              FT  Applied Scientist  213660
# 25         2023               EN              FT  Applied Scientist  130760
# 505        2023               SE              FT  Applied Scientist  222200
# 506        2023               SE              FT  Applied Scientist  136000
# 553        2023               SE              FT  Applied Scientist  309400
# 554        2023               SE              FT  Applied Scientist  159100
# 626        2023               SE              FT  Applied Scientist  309400
# ...

# %% [markdown]
# ### Matlplotlib:
# -  It is used for Data visualization.
#  - mat -> mathematical data
#  - plot -> charts/graphs
#  - lib -> library
#  - first we need to import matplotlib
#  - By usin pyplot module we can draw the graphs
#  - Syntax:
#            - from matplotlib import pyplot as plt

# %%
#import matplotlib library
from matplotlib import pyplot as plt

# %%
#simple line graph..
x =[10,20,30,40,50]
y=[20,30,40,50,60]
plt.plot(x,y)
plt.show()

# %%
# apply x ,y label
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
#title
plt.title("simple line graph")
plt.show()

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
#apply styles,markers,colors...
#line style->ls
#colors->c
#markersmm
#marker face color->mfc
#marker edge color ->mec
#line width -> lw
#marker size -> ms
plt.plot(x,y,c="green")
plt.show()

# %%
x1 = [10,20,30,40]
y1 = [5,10,15,20]
plt.plot(x1,y1,c="g", marker = "d", mfc = "y", mec = "r", ms = 20,lw = 10)
plt.grid() # To add the grid lines
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("simple graph")
# Out:
# Text(0.5, 1.0, 'simple graph')

# %%
#multiple line graphs.
#legend function.
x=[1,2,3,4]
y1=[1,3,4,5]
y2=[4,5,6,7]
plt.plot(x,y1,label='squares')
plt.plot(x,y2,label='cubes')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Bar Graph
# - By using bar() function we can develop the bar graph
# syntax:
# plt.bar(categories,array_values)
# - Two types of bar graphs.
# - 1.vertical bar graph-> bar()
# - 2.Horizontal bar graph -> barh()

# %%
# example on bar graph..
subjects=['java','python','dbms','flat']
marks=[20,30,40,50]
plt.bar(subjects,marks,color=['g','r','y','c'],edgecolor="b")
# Out:
# <BarContainer object of 4 artists>

# %%
# example on horozontal bar graph..
subjects=['java','python','dbms','flat']
marks=[20,30,40,50]
plt.barh(subjects,marks,color=['g','r','y','c'],edgecolor="b")
# Out:
# <BarContainer object of 4 artists>

# %%
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
# ...

# %%
x=['2023','2022','2021','2020']
y=df['work_year'].value_counts()
plt.bar(x,y)
plt.show()

# %%
df['job_title'].value_counts()
# Out:
# Data Engineer                1040
# Data Scientist                840
# Data Analyst                  614
# Machine Learning Engineer     291
# Analytics Engineer            103
#                              ...
# Compliance Data Analyst         1
# BI Data Engineer                1
# Deep Learning Researcher        1
# Head of Machine Learning        1
# Staff Data Analyst              1
# Name: job_title, Length: 93, dtype: int64

# %% [markdown]
# ### Scatter Plot
# - By using scatter () function we can the scatter plot.
# - plt.scatter(x,y)
# - it is represented by dot(.)

# %%
#Example of Scatter plot.
x=[1,3,4,5,6,7,8]
y=[5,3,6,7,8,6,5]
plt.scatter(x,y,color='g')
plt.grid()

# %% [markdown]
# ### Pie Chart:
# - plt.pie(x,labels=names)

# %%
#example on pie chart.
names=['a','b','c','d']
per=[23,45,67,64]
plt.pie(per,labels=names)
plt.legend(title='-  Activities')
plt.show()

# %% [markdown]
# ###  Histograms

# %%
#Example on HGistogram.
import numpy as np
n1=np.random.randint(10,100,45)
plt.hist(n1)
plt.show()
